# %%
import pandas as pd

data = pd.read_csv('IMDb_Top_250_Movies.csv')

# %% [markdown]
# ### Histogram by Year

# %%
data.hist('Year')
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>]], dtype=object)

# %% [markdown]
# ### Histogram by IMDb rating

# %%
data.hist('IMDb rating')
# Out:
# array([[<AxesSubplot:title={'center':'IMDb rating'}>]], dtype=object)

# %% [markdown]
# ### IMDb average rating of the top 250 movies

# %%
round(data['IMDb rating'].mean(), 2)
# Out:
# 8.25

# %% [markdown]
# ### Top 10 movies

# %%
data.iloc[:10]
# Out:
#   Movie title                                                           Year  \
# 0  The Shawshank Redemption                      ...                    1994
# 1  The Godfather                                 ...                    1972
# 2  The Dark Knight                               ...                    2008
# 3  The Godfather Part II                         ...                    1974
# 4  12 Angry Men                                  ...                    1957
# 5  Schindler's List                              ...                    1993
# 6  The Lord of the Rings: The Return of the King ...                    2003
# 7  Pulp Fiction                                  ...                    1994
# 8  The Lord of the Rings: The Fellowship of the R...                    2001
# 9  Il buono, il brutto, il cattivo               ...                    1966
#
#    IMDb rating
# 0          9.2
# 1          9.2
# 2          9.0
# 3          9.0
# 4          8.9
# 5          8.9
# ...

# %% [markdown]
# ### Top 10 movies upside down

# %%
data.iloc[-10:]
# Out:
#     Movie title                                                           \
# 240  Life of Brian                                 ...
# 241  Dersu Uzala                                   ...
# 242  It Happened One Night                         ...
# 243  The Sound of Music                            ...
# 244  Ah-ga-ssi                                     ...
# 245  Aladdin                                       ...
# 246  Jai Bhim                                      ...
# 247  Gandhi                                        ...
# 248  The Help                                      ...
# 249  Beauty and the Beast                          ...
#
#      Year  IMDb rating
# 240  1979          8.0
# 241  1975          8.0
# 242  1934          8.0
# 243  1965          8.0
# 244  2016          8.0
# 245  1992          8.0
# 246  2021          8.0
# 247  1982          8.0
# 248  2011          8.0
# 249  1991          8.0

# %% [markdown]
# ### Total movies by IMDb rating

# %% [markdown]
# #### >= 9.0

# %%
data[data['IMDb rating'] >= 9]
# Out:
#   Movie title                                                           Year  \
# 0  The Shawshank Redemption                      ...                    1994
# 1  The Godfather                                 ...                    1972
# 2  The Dark Knight                               ...                    2008
# 3  The Godfather Part II                         ...                    1974
#
#    IMDb rating
# 0          9.2
# 1          9.2
# 2          9.0
# 3          9.0

# %% [markdown]
# #### 8.5 <= x < 9.0

# %%
data[(data['IMDb rating'] >= 8.5) & (data['IMDb rating'] < 9)]
# Out:
#    Movie title                                                           Year  \
# 4   12 Angry Men                                  ...                    1957
# 5   Schindler's List                              ...                    1993
# 6   The Lord of the Rings: The Return of the King ...                    2003
# 7   Pulp Fiction                                  ...                    1994
# 8   The Lord of the Rings: The Fellowship of the R...                    2001
# 9   Il buono, il brutto, il cattivo               ...                    1966
# 10  Forrest Gump                                  ...                    1994
# 11  Fight Club                                    ...                    1999
# 12  Inception                                     ...                    2010
# 13  The Lord of the Rings: The Two Towers         ...                    2002
# 14  The Empire Strikes Back                       ...                    1980
# ...

# %% [markdown]
# #### < 8.5

# %%
data[data['IMDb rating'] < 8.5]
# Out:
#     Movie title                                                           \
# 45   Modern Times                                  ...
# 46   Seppuku                                       ...
# 47   Hotaru no haka                                ...
# 48   Once Upon a Time in the West                  ...
# 49   Rear Window                                   ...
# ..                                                 ...
# 245  Aladdin                                       ...
# 246  Jai Bhim                                      ...
# 247  Gandhi                                        ...
# 248  The Help                                      ...
# 249  Beauty and the Beast                          ...
#
#      Year  IMDb rating
# 45   1936          8.4
# 46   1962          8.4
# 47   1988          8.4
# 48   1968          8.4
# 49   1954          8.4
# ..    ...          ...
# 245  1992          8.0
# 246  2021          8.0
# 247  1982          8.0
# 248  2011          8.0
# ...
